# %% [markdown]
# http://dbdesc.com/output_samples/htmlbrowse_northwind.html

# %% [markdown]
# # Case Study: Northwind Traders

# %% [markdown]
# ## get sql db into merged pandas df
# ie, aggregate all necessary data into one table/array

# %% [markdown]
# ##### import packages and modules

# %%
import pandas as pd
import numpy as np
from scipy.stats import kurtosis, skew
import scipy.stats as stats
from math import sqrt
import math
import copy

import sqlalchemy
from sqlalchemy import create_engine
from sqlalchemy.orm import session, sessionmaker
from sqlalchemy import inspect # so we can perform high level investigations


import seaborn as sns

import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('seaborn')
from matplotlib import style

pd.set_option('display.max_columns', None)

# %% [markdown]
# ##### creating an engine object and a session to connect and work with the Northwind sql db

# %%
engine = create_engine("sqlite:///Northwind_small.sqlite", echo = True)
Session = sessionmaker(bind = engine)
session = Session
inspector = inspect(engine)
# Out:
# 2019-04-28 20:37:03,642 INFO sqlalchemy.engine.base.Engine SELECT CAST('test plain returns' AS VARCHAR(60)) AS anon_1
# 2019-04-28 20:37:03,646 INFO sqlalchemy.engine.base.Engine ()
# 2019-04-28 20:37:03,647 INFO sqlalchemy.engine.base.Engine SELECT CAST('test unicode returns' AS VARCHAR(60)) AS anon_1
# 2019-04-28 20:37:03,648 INFO sqlalchemy.engine.base.Engine ()

# %% [markdown]
# ##### looking at the table names

# %%
inspector.get_table_names()
# Out:
# 2019-04-28 20:37:03,655 INFO sqlalchemy.engine.base.Engine SELECT name FROM sqlite_master WHERE type='table' ORDER BY name
# 2019-04-28 20:37:03,655 INFO sqlalchemy.engine.base.Engine ()
# ['Category',
#  'Customer',
#  'CustomerCustomerDemo',
#  'CustomerDemographic',
#  'Employee',
#  'EmployeeTerritory',
#  'Order',
#  'OrderDetail',
#  'Product',
#  'Region',
#  'Shipper',
#  'Supplier',
#  'Territory']

# %% [markdown]
# ##### For the first question, we only need Quantity and Discount though, I will aggregate all tables since we will need them later

# %% [markdown]
# ##### map the db table features with their headings

# %%
from sqlalchemy import MetaData
from sqlalchemy.ext.automap import automap_base # creates a framework that clones the db structure so that it can generate a 
                                                  # a new model in which to map the db with its metadata, ie, column headings

# %%
metadata = MetaData()
metadata.reflect(engine)
Base = automap_base(metadata = metadata)
Base.prepare()



Category, Customer, CustomerCustomerDemo, CustomerDemographic, Employee, EmployeeTerritory, Order, OrderDetail,\
Product, Region, Shipper, Supplier, Territory = \
Base.classes.Category,\
Base.classes.Customer,\
Base.classes.CustomerCustomerDemo,\
Base.classes.CustomerDemographic, \
Base.classes.Employee, \
Base.classes.EmployeeTerritory,\
Base.classes.Order,\
Base.classes.OrderDetail, \
Base.classes.Product, \
Base.classes.Region,\
Base.classes.Shipper, \
Base.classes.Supplier, \
Base.classes.Territory
# Out:
# 2019-04-28 20:37:03,679 INFO sqlalchemy.engine.base.Engine SELECT name FROM sqlite_master WHERE type='table' ORDER BY name
# 2019-04-28 20:37:03,681 INFO sqlalchemy.engine.base.Engine ()
# 2019-04-28 20:37:03,684 INFO sqlalchemy.engine.base.Engine PRAGMA table_info("Category")
# 2019-04-28 20:37:03,685 INFO sqlalchemy.engine.base.Engine ()
# 2019-04-28 20:37:03,687 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = 'Category' AND type = 'table'
# 2019-04-28 20:37:03,688 INFO sqlalchemy.engine.base.Engine ()
# 2019-04-28 20:37:03,689 INFO sqlalchemy.engine.base.Engine PRAGMA foreign_key_list("Category")
# 2019-04-28 20:37:03,690 INFO sqlalchemy.engine.base.Engine ()
# 2019-04-28 20:37:03,691 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = 'Category' AND type = 'table'
# 2019-04-28 20:37:03,691 INFO sqlalchemy.engine.base.Engine ()
# 2019-04-28 20:37:03,694 INFO sqlalchemy.engine.base.Engine PRAGMA index_list("Category")
# 2019-04-28 20:37:03,695 INFO sqlalchemy.engine.base.Engine ()
# 2019-04-28 20:37:03,697 INFO sqlalchemy.engine.base.Engine PRAGMA index_list("Category")
# 2019-04-28 20:37:03,697 INFO sqlalchemy.engine.base.Engine ()
# 2019-04-28 20:37:03,698 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = 'Category' AND type = 'table'
# 2019-04-28 20:37:03,699 INFO sqlalchemy.engine.base.Engine ()
# 2019-04-28 20:37:03,702 INFO sqlalchemy.engine.base.Engine PRAGMA table_info("Customer")
# 2019-04-28 20:37:03,702 INFO sqlalchemy.engine.base.Engine ()
# 2019-04-28 20:37:03,704 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = 'Customer' AND type = 'table'
# 2019-04-28 20:37:03,705 INFO sqlalchemy.engine.base.Engine ()
# 2019-04-28 20:37:03,706 INFO sqlalchemy.engine.base.Engine PRAGMA foreign_key_list("Customer")
# 2019-04-28 20:37:03,707 INFO sqlalchemy.engine.base.Engine ()
# 2019-04-28 20:37:03,708 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = 'Customer' AND type = 'table'
# 2019-04-28 20:37:03,709 INFO sqlalchemy.engine.base.Engine ()
# 2019-04-28 20:37:03,711 INFO sqlalchemy.engine.base.Engine PRAGMA index_list("Customer")
# 2019-04-28 20:37:03,712 INFO sqlalchemy.engine.base.Engine ()
# 2019-04-28 20:37:03,714 INFO sqlalchemy.engine.base.Engine PRAGMA index_list("Customer")
# 2019-04-28 20:37:03,715 INFO sqlalchemy.engine.base.Engine ()
# 2019-04-28 20:37:03,716 INFO sqlalchemy.engine.base.Engine PRAGMA index_info("sqlite_autoindex_Customer_1")
# 2019-04-28 20:37:03,717 INFO sqlalchemy.engine.base.Engine ()
# 2019-04-28 20:37:03,717 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = 'Customer' AND type = 'table'
# 2019-04-28 20:37:03,718 INFO sqlalchemy.engine.base.Engine ()
# 2019-04-28 20:37:03,720 INFO sqlalchemy.engine.base.Engine PRAGMA table_info("CustomerCustomerDemo")
# 2019-04-28 20:37:03,720 INFO sqlalchemy.engine.base.Engine ()
# 2019-04-28 20:37:03,721 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = 'CustomerCustomerDemo' AND type = 'table'
# 2019-04-28 20:37:03,722 INFO sqlalchemy.engine.base.Engine ()
# 2019-04-28 20:37:03,723 INFO sqlalchemy.engine.base.Engine PRAGMA foreign_key_list("CustomerCustomerDemo")
# 2019-04-28 20:37:03,723 INFO sqlalchemy.engine.base.Engine ()
# 2019-04-28 20:37:03,724 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = 'CustomerCustomerDemo' AND type = 'table'
# 2019-04-28 20:37:03,725 INFO sqlalchemy.engine.base.Engine ()
# 2019-04-28 20:37:03,726 INFO sqlalchemy.engine.base.Engine PRAGMA index_list("CustomerCustomerDemo")
# 2019-04-28 20:37:03,727 INFO sqlalchemy.engine.base.Engine ()
# 2019-04-28 20:37:03,728 INFO sqlalchemy.engine.base.Engine PRAGMA index_list("CustomerCustomerDemo")
# 2019-04-28 20:37:03,729 INFO sqlalchemy.engine.base.Engine ()
# 2019-04-28 20:37:03,730 INFO sqlalchemy.engine.base.Engine PRAGMA index_info("sqlite_autoindex_CustomerCustomerDemo_1")
# 2019-04-28 20:37:03,731 INFO sqlalchemy.engine.base.Engine ()
# 2019-04-28 20:37:03,733 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = 'CustomerCustomerDemo' AND type = 'table'
# 2019-04-28 20:37:03,734 INFO sqlalchemy.engine.base.Engine ()
# 2019-04-28 20:37:03,735 INFO sqlalchemy.engine.base.Engine PRAGMA table_info("CustomerDemographic")
# 2019-04-28 20:37:03,736 INFO sqlalchemy.engine.base.Engine ()
# 2019-04-28 20:37:03,737 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = 'CustomerDemographic' AND type = 'table'
# 2019-04-28 20:37:03,737 INFO sqlalchemy.engine.base.Engine ()
# 2019-04-28 20:37:03,739 INFO sqlalchemy.engine.base.Engine PRAGMA foreign_key_list("CustomerDemographic")
# 2019-04-28 20:37:03,739 INFO sqlalchemy.engine.base.Engine ()
# 2019-04-28 20:37:03,740 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = 'CustomerDemographic' AND type = 'table'
# 2019-04-28 20:37:03,740 INFO sqlalchemy.engine.base.Engine ()
# 2019-04-28 20:37:03,741 INFO sqlalchemy.engine.base.Engine PRAGMA index_list("CustomerDemographic")
# 2019-04-28 20:37:03,742 INFO sqlalchemy.engine.base.Engine ()
# 2019-04-28 20:37:03,743 INFO sqlalchemy.engine.base.Engine PRAGMA index_list("CustomerDemographic")
# 2019-04-28 20:37:03,743 INFO sqlalchemy.engine.base.Engine ()
# 2019-04-28 20:37:03,744 INFO sqlalchemy.engine.base.Engine PRAGMA index_info("sqlite_autoindex_CustomerDemographic_1")
# 2019-04-28 20:37:03,745 INFO sqlalchemy.engine.base.Engine ()
# 2019-04-28 20:37:03,747 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = 'CustomerDemographic' AND type = 'table'
# 2019-04-28 20:37:03,747 INFO sqlalchemy.engine.base.Engine ()
# 2019-04-28 20:37:03,749 INFO sqlalchemy.engine.base.Engine PRAGMA table_info("Employee")
# 2019-04-28 20:37:03,749 INFO sqlalchemy.engine.base.Engine ()
# 2019-04-28 20:37:03,751 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = 'Employee' AND type = 'table'
# 2019-04-28 20:37:03,752 INFO sqlalchemy.engine.base.Engine ()
# 2019-04-28 20:37:03,754 INFO sqlalchemy.engine.base.Engine PRAGMA foreign_key_list("Employee")
# 2019-04-28 20:37:03,755 INFO sqlalchemy.engine.base.Engine ()
# 2019-04-28 20:37:03,756 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = 'Employee' AND type = 'table'
# 2019-04-28 20:37:03,757 INFO sqlalchemy.engine.base.Engine ()
# 2019-04-28 20:37:03,759 INFO sqlalchemy.engine.base.Engine PRAGMA index_list("Employee")
# 2019-04-28 20:37:03,759 INFO sqlalchemy.engine.base.Engine ()
# 2019-04-28 20:37:03,761 INFO sqlalchemy.engine.base.Engine PRAGMA index_list("Employee")
# 2019-04-28 20:37:03,761 INFO sqlalchemy.engine.base.Engine ()
# 2019-04-28 20:37:03,763 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = 'Employee' AND type = 'table'
# 2019-04-28 20:37:03,764 INFO sqlalchemy.engine.base.Engine ()
# 2019-04-28 20:37:03,765 INFO sqlalchemy.engine.base.Engine PRAGMA table_info("EmployeeTerritory")
# 2019-04-28 20:37:03,766 INFO sqlalchemy.engine.base.Engine ()
# 2019-04-28 20:37:03,767 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = 'EmployeeTerritory' AND type = 'table'
# 2019-04-28 20:37:03,768 INFO sqlalchemy.engine.base.Engine ()
# 2019-04-28 20:37:03,769 INFO sqlalchemy.engine.base.Engine PRAGMA foreign_key_list("EmployeeTerritory")
# 2019-04-28 20:37:03,770 INFO sqlalchemy.engine.base.Engine ()
# 2019-04-28 20:37:03,771 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = 'EmployeeTerritory' AND type = 'table'
# 2019-04-28 20:37:03,772 INFO sqlalchemy.engine.base.Engine ()
# 2019-04-28 20:37:03,773 INFO sqlalchemy.engine.base.Engine PRAGMA index_list("EmployeeTerritory")
# 2019-04-28 20:37:03,773 INFO sqlalchemy.engine.base.Engine ()
# 2019-04-28 20:37:03,774 INFO sqlalchemy.engine.base.Engine PRAGMA index_list("EmployeeTerritory")
# 2019-04-28 20:37:03,774 INFO sqlalchemy.engine.base.Engine ()
# 2019-04-28 20:37:03,775 INFO sqlalchemy.engine.base.Engine PRAGMA index_info("sqlite_autoindex_EmployeeTerritory_1")
# 2019-04-28 20:37:03,776 INFO sqlalchemy.engine.base.Engine ()
# 2019-04-28 20:37:03,777 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = 'EmployeeTerritory' AND type = 'table'
# 2019-04-28 20:37:03,777 INFO sqlalchemy.engine.base.Engine ()
# 2019-04-28 20:37:03,779 INFO sqlalchemy.engine.base.Engine PRAGMA table_info("Order")
# 2019-04-28 20:37:03,779 INFO sqlalchemy.engine.base.Engine ()
# 2019-04-28 20:37:03,781 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = 'Order' AND type = 'table'
# 2019-04-28 20:37:03,781 INFO sqlalchemy.engine.base.Engine ()
# 2019-04-28 20:37:03,783 INFO sqlalchemy.engine.base.Engine PRAGMA foreign_key_list("Order")
# 2019-04-28 20:37:03,783 INFO sqlalchemy.engine.base.Engine ()
# 2019-04-28 20:37:03,784 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = 'Order' AND type = 'table'
# 2019-04-28 20:37:03,784 INFO sqlalchemy.engine.base.Engine ()
# 2019-04-28 20:37:03,785 INFO sqlalchemy.engine.base.Engine PRAGMA index_list("Order")
# 2019-04-28 20:37:03,786 INFO sqlalchemy.engine.base.Engine ()
# 2019-04-28 20:37:03,786 INFO sqlalchemy.engine.base.Engine PRAGMA index_list("Order")
# 2019-04-28 20:37:03,787 INFO sqlalchemy.engine.base.Engine ()
# 2019-04-28 20:37:03,788 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = 'Order' AND type = 'table'
# 2019-04-28 20:37:03,788 INFO sqlalchemy.engine.base.Engine ()
# 2019-04-28 20:37:03,789 INFO sqlalchemy.engine.base.Engine PRAGMA table_info("OrderDetail")
# 2019-04-28 20:37:03,790 INFO sqlalchemy.engine.base.Engine ()
# 2019-04-28 20:37:03,791 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = 'OrderDetail' AND type = 'table'
# 2019-04-28 20:37:03,792 INFO sqlalchemy.engine.base.Engine ()
# 2019-04-28 20:37:03,793 INFO sqlalchemy.engine.base.Engine PRAGMA foreign_key_list("OrderDetail")
# 2019-04-28 20:37:03,793 INFO sqlalchemy.engine.base.Engine ()
# 2019-04-28 20:37:03,794 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = 'OrderDetail' AND type = 'table'
# 2019-04-28 20:37:03,794 INFO sqlalchemy.engine.base.Engine ()
# 2019-04-28 20:37:03,795 INFO sqlalchemy.engine.base.Engine PRAGMA index_list("OrderDetail")
# 2019-04-28 20:37:03,796 INFO sqlalchemy.engine.base.Engine ()
# 2019-04-28 20:37:03,798 INFO sqlalchemy.engine.base.Engine PRAGMA index_list("OrderDetail")
# 2019-04-28 20:37:03,798 INFO sqlalchemy.engine.base.Engine ()
# 2019-04-28 20:37:03,800 INFO sqlalchemy.engine.base.Engine PRAGMA index_info("sqlite_autoindex_OrderDetail_1")
# 2019-04-28 20:37:03,801 INFO sqlalchemy.engine.base.Engine ()
# 2019-04-28 20:37:03,802 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = 'OrderDetail' AND type = 'table'
# 2019-04-28 20:37:03,802 INFO sqlalchemy.engine.base.Engine ()
# 2019-04-28 20:37:03,804 INFO sqlalchemy.engine.base.Engine PRAGMA table_info("Product")
# 2019-04-28 20:37:03,804 INFO sqlalchemy.engine.base.Engine ()
# 2019-04-28 20:37:03,806 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = 'Product' AND type = 'table'
# 2019-04-28 20:37:03,807 INFO sqlalchemy.engine.base.Engine ()
# 2019-04-28 20:37:03,808 INFO sqlalchemy.engine.base.Engine PRAGMA foreign_key_list("Product")
# 2019-04-28 20:37:03,808 INFO sqlalchemy.engine.base.Engine ()
# 2019-04-28 20:37:03,809 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = 'Product' AND type = 'table'
# 2019-04-28 20:37:03,809 INFO sqlalchemy.engine.base.Engine ()
# 2019-04-28 20:37:03,810 INFO sqlalchemy.engine.base.Engine PRAGMA index_list("Product")
# 2019-04-28 20:37:03,811 INFO sqlalchemy.engine.base.Engine ()
# 2019-04-28 20:37:03,812 INFO sqlalchemy.engine.base.Engine PRAGMA index_list("Product")
# 2019-04-28 20:37:03,813 INFO sqlalchemy.engine.base.Engine ()
# 2019-04-28 20:37:03,814 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = 'Product' AND type = 'table'
# 2019-04-28 20:37:03,815 INFO sqlalchemy.engine.base.Engine ()
# 2019-04-28 20:37:03,816 INFO sqlalchemy.engine.base.Engine PRAGMA table_info("Region")
# 2019-04-28 20:37:03,816 INFO sqlalchemy.engine.base.Engine ()
# 2019-04-28 20:37:03,818 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = 'Region' AND type = 'table'
# 2019-04-28 20:37:03,818 INFO sqlalchemy.engine.base.Engine ()
# 2019-04-28 20:37:03,819 INFO sqlalchemy.engine.base.Engine PRAGMA foreign_key_list("Region")
# 2019-04-28 20:37:03,820 INFO sqlalchemy.engine.base.Engine ()
# 2019-04-28 20:37:03,820 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = 'Region' AND type = 'table'
# 2019-04-28 20:37:03,821 INFO sqlalchemy.engine.base.Engine ()
# 2019-04-28 20:37:03,822 INFO sqlalchemy.engine.base.Engine PRAGMA index_list("Region")
# 2019-04-28 20:37:03,822 INFO sqlalchemy.engine.base.Engine ()
# 2019-04-28 20:37:03,823 INFO sqlalchemy.engine.base.Engine PRAGMA index_list("Region")
# 2019-04-28 20:37:03,823 INFO sqlalchemy.engine.base.Engine ()
# 2019-04-28 20:37:03,824 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = 'Region' AND type = 'table'
# 2019-04-28 20:37:03,825 INFO sqlalchemy.engine.base.Engine ()
# 2019-04-28 20:37:03,826 INFO sqlalchemy.engine.base.Engine PRAGMA table_info("Shipper")
# 2019-04-28 20:37:03,826 INFO sqlalchemy.engine.base.Engine ()
# 2019-04-28 20:37:03,828 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = 'Shipper' AND type = 'table'
# 2019-04-28 20:37:03,829 INFO sqlalchemy.engine.base.Engine ()
# 2019-04-28 20:37:03,830 INFO sqlalchemy.engine.base.Engine PRAGMA foreign_key_list("Shipper")
# 2019-04-28 20:37:03,831 INFO sqlalchemy.engine.base.Engine ()
# 2019-04-28 20:37:03,832 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = 'Shipper' AND type = 'table'
# 2019-04-28 20:37:03,832 INFO sqlalchemy.engine.base.Engine ()
# 2019-04-28 20:37:03,833 INFO sqlalchemy.engine.base.Engine PRAGMA index_list("Shipper")
# 2019-04-28 20:37:03,833 INFO sqlalchemy.engine.base.Engine ()
# 2019-04-28 20:37:03,834 INFO sqlalchemy.engine.base.Engine PRAGMA index_list("Shipper")
# 2019-04-28 20:37:03,835 INFO sqlalchemy.engine.base.Engine ()
# 2019-04-28 20:37:03,836 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = 'Shipper' AND type = 'table'
# 2019-04-28 20:37:03,837 INFO sqlalchemy.engine.base.Engine ()
# 2019-04-28 20:37:03,838 INFO sqlalchemy.engine.base.Engine PRAGMA table_info("Supplier")
# 2019-04-28 20:37:03,839 INFO sqlalchemy.engine.base.Engine ()
# 2019-04-28 20:37:03,841 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = 'Supplier' AND type = 'table'
# 2019-04-28 20:37:03,841 INFO sqlalchemy.engine.base.Engine ()
# 2019-04-28 20:37:03,843 INFO sqlalchemy.engine.base.Engine PRAGMA foreign_key_list("Supplier")
# 2019-04-28 20:37:03,843 INFO sqlalchemy.engine.base.Engine ()
# 2019-04-28 20:37:03,844 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = 'Supplier' AND type = 'table'
# 2019-04-28 20:37:03,845 INFO sqlalchemy.engine.base.Engine ()
# 2019-04-28 20:37:03,846 INFO sqlalchemy.engine.base.Engine PRAGMA index_list("Supplier")
# 2019-04-28 20:37:03,847 INFO sqlalchemy.engine.base.Engine ()
# 2019-04-28 20:37:03,848 INFO sqlalchemy.engine.base.Engine PRAGMA index_list("Supplier")
# 2019-04-28 20:37:03,848 INFO sqlalchemy.engine.base.Engine ()
# 2019-04-28 20:37:03,849 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = 'Supplier' AND type = 'table'
# 2019-04-28 20:37:03,849 INFO sqlalchemy.engine.base.Engine ()
# 2019-04-28 20:37:03,851 INFO sqlalchemy.engine.base.Engine PRAGMA table_info("Territory")
# 2019-04-28 20:37:03,851 INFO sqlalchemy.engine.base.Engine ()
# 2019-04-28 20:37:03,853 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = 'Territory' AND type = 'table'
# 2019-04-28 20:37:03,853 INFO sqlalchemy.engine.base.Engine ()
# 2019-04-28 20:37:03,854 INFO sqlalchemy.engine.base.Engine PRAGMA foreign_key_list("Territory")
# 2019-04-28 20:37:03,855 INFO sqlalchemy.engine.base.Engine ()
# 2019-04-28 20:37:03,856 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = 'Territory' AND type = 'table'
# 2019-04-28 20:37:03,857 INFO sqlalchemy.engine.base.Engine ()
# 2019-04-28 20:37:03,858 INFO sqlalchemy.engine.base.Engine PRAGMA index_list("Territory")
# 2019-04-28 20:37:03,858 INFO sqlalchemy.engine.base.Engine ()
# 2019-04-28 20:37:03,859 INFO sqlalchemy.engine.base.Engine PRAGMA index_list("Territory")
# 2019-04-28 20:37:03,860 INFO sqlalchemy.engine.base.Engine ()
# 2019-04-28 20:37:03,861 INFO sqlalchemy.engine.base.Engine PRAGMA index_info("sqlite_autoindex_Territory_1")
# 2019-04-28 20:37:03,861 INFO sqlalchemy.engine.base.Engine ()
# 2019-04-28 20:37:03,863 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = 'Territory' AND type = 'table'
# 2019-04-28 20:37:03,864 INFO sqlalchemy.engine.base.Engine ()

# %% [markdown]
# ##### converting each table to a pandas dataframe

# %%
category_df= pd.read_sql_query("SELECT * FROM [category]", engine)
customer_df = pd.read_sql_query("SELECT * FROM [customer]", engine)
customerCustomerDemo_df = pd.read_sql_query("SELECT * FROM [customerCustomerDemo]", engine)
customerDemographic_df = pd.read_sql_query("SELECT * FROM [customerDemographic]", engine)
employee_df = pd.read_sql_query("SELECT * FROM [employee]", engine)
employeeTerritory_df = pd.read_sql_query("SELECT * FROM [employeeTerritory]", engine)
order_df = pd.read_sql_query("SELECT * FROM [order]", engine)
orderDetail_df = pd.read_sql_query("SELECT * FROM [orderDetail]", engine)
product_df = pd.read_sql_query("SELECT * FROM [product]", engine)
region_df = pd.read_sql_query("SELECT * FROM [region]", engine)
shipper_df = pd.read_sql_query("SELECT * FROM [shipper]", engine)
supplier_df = pd.read_sql_query("SELECT * FROM [supplier]", engine)
territory_df = pd.read_sql_query("SELECT * FROM [territory]", engine)
# Out:
# 2019-04-28 20:37:03,892 INFO sqlalchemy.engine.base.Engine SELECT * FROM [category]
# 2019-04-28 20:37:03,893 INFO sqlalchemy.engine.base.Engine ()
# 2019-04-28 20:37:03,898 INFO sqlalchemy.engine.base.Engine SELECT * FROM [customer]
# 2019-04-28 20:37:03,898 INFO sqlalchemy.engine.base.Engine ()
# 2019-04-28 20:37:03,906 INFO sqlalchemy.engine.base.Engine SELECT * FROM [customerCustomerDemo]
# 2019-04-28 20:37:03,907 INFO sqlalchemy.engine.base.Engine ()
# 2019-04-28 20:37:03,911 INFO sqlalchemy.engine.base.Engine SELECT * FROM [customerDemographic]
# 2019-04-28 20:37:03,911 INFO sqlalchemy.engine.base.Engine ()
# 2019-04-28 20:37:03,916 INFO sqlalchemy.engine.base.Engine SELECT * FROM [employee]
# 2019-04-28 20:37:03,916 INFO sqlalchemy.engine.base.Engine ()
# 2019-04-28 20:37:03,922 INFO sqlalchemy.engine.base.Engine SELECT * FROM [employeeTerritory]
# 2019-04-28 20:37:03,922 INFO sqlalchemy.engine.base.Engine ()
# 2019-04-28 20:37:03,926 INFO sqlalchemy.engine.base.Engine SELECT * FROM [order]
# 2019-04-28 20:37:03,927 INFO sqlalchemy.engine.base.Engine ()
# 2019-04-28 20:37:03,957 INFO sqlalchemy.engine.base.Engine SELECT * FROM [orderDetail]
# 2019-04-28 20:37:03,958 INFO sqlalchemy.engine.base.Engine ()
# 2019-04-28 20:37:03,987 INFO sqlalchemy.engine.base.Engine SELECT * FROM [product]
# 2019-04-28 20:37:03,987 INFO sqlalchemy.engine.base.Engine ()
# 2019-04-28 20:37:03,994 INFO sqlalchemy.engine.base.Engine SELECT * FROM [region]
# 2019-04-28 20:37:03,995 INFO sqlalchemy.engine.base.Engine ()
# 2019-04-28 20:37:03,998 INFO sqlalchemy.engine.base.Engine SELECT * FROM [shipper]
# 2019-04-28 20:37:03,999 INFO sqlalchemy.engine.base.Engine ()
# 2019-04-28 20:37:04,002 INFO sqlalchemy.engine.base.Engine SELECT * FROM [supplier]
# 2019-04-28 20:37:04,003 INFO sqlalchemy.engine.base.Engine ()
# 2019-04-28 20:37:04,009 INFO sqlalchemy.engine.base.Engine SELECT * FROM [territory]
# 2019-04-28 20:37:04,010 INFO sqlalchemy.engine.base.Engine ()

# %%
product_df.head()
# Out:
#    Id                   ProductName  SupplierId  CategoryId  \
# 0   1                          Chai           1           1
# 1   2                         Chang           1           1
# 2   3                 Aniseed Syrup           1           2
# 3   4  Chef Anton's Cajun Seasoning           2           2
# 4   5        Chef Anton's Gumbo Mix           2           2
#
#        QuantityPerUnit  UnitPrice  UnitsInStock  UnitsOnOrder  ReorderLevel  \
# 0   10 boxes x 20 bags      18.00            39             0            10
# 1   24 - 12 oz bottles      19.00            17            40            25
# 2  12 - 550 ml bottles      10.00            13            70            25
# 3       48 - 6 oz jars      22.00            53             0             0
# 4             36 boxes      21.35             0             0             0
#
#    Discontinued
# 0             0
# 1             0
# 2             0
# 3             0
# 4             1

# %%
orderDetail_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2155 entries, 0 to 2154
# Data columns (total 6 columns):
# Id           2155 non-null object
# OrderId      2155 non-null int64
# ProductId    2155 non-null int64
# UnitPrice    2155 non-null float64
# Quantity     2155 non-null int64
# Discount     2155 non-null float64
# dtypes: float64(2), int64(3), object(1)
# memory usage: 101.1+ KB

# %%
order_df.head()
# Out:
#       Id CustomerId  EmployeeId   OrderDate RequiredDate ShippedDate  ShipVia  \
# 0  10248      VINET           5  2012-07-04   2012-08-01  2012-07-16        3
# 1  10249      TOMSP           6  2012-07-05   2012-08-16  2012-07-10        1
# 2  10250      HANAR           4  2012-07-08   2012-08-05  2012-07-12        2
# 3  10251      VICTE           3  2012-07-08   2012-08-05  2012-07-15        1
# 4  10252      SUPRD           4  2012-07-09   2012-08-06  2012-07-11        2
#
#    Freight                   ShipName           ShipAddress        ShipCity  \
# 0    32.38  Vins et alcools Chevalier    59 rue de l'Abbaye           Reims
# 1    11.61         Toms Spezialitäten         Luisenstr. 48         Münster
# 2    65.83              Hanari Carnes       Rua do Paço, 67  Rio de Janeiro
# 3    41.34       Victuailles en stock    2, rue du Commerce            Lyon
# 4    51.30           Suprêmes délices  Boulevard Tirou, 255       Charleroi
#
#        ShipRegion ShipPostalCode ShipCountry
# 0  Western Europe          51100      France
# 1  Western Europe          44087     Germany
# 2   South America      05454-876      Brazil
# 3  Western Europe          69004      France
# 4  Western Europe         B-6000     Belgium

# %%
all_df = list([
category_df,
customer_df ,
customerCustomerDemo_df, 
customerDemographic_df ,
employee_df ,
employeeTerritory_df, 
order_df ,
orderDetail_df, 
product_df ,
region_df ,
shipper_df ,
supplier_df ,
territory_df ])

# %%
for i in all_df:
    print(len(i))
# Out:
# 8
# 91
# 0
# 0
# 9
# 49
# 830
# 2155
# 77
# 4
# 3
# 29
# 53

# %% [markdown]
# ##### will join the following tables which will have useful info for further insights<br>
# * category
# * customer
# * order
# * order detail
# * product

# %% [markdown]
# ##### must amend name for id column on Category table so I can complete a merge statement

# %%
category_df.rename(columns = {"Id":"CategoryId"}, inplace = True)

# %%
category_df.head()
# Out:
#    CategoryId    CategoryName  \
# 0           1       Beverages
# 1           2      Condiments
# 2           3     Confections
# 3           4  Dairy Products
# 4           5  Grains/Cereals
#
#                                          Description
# 0        Soft drinks, coffees, teas, beers, and ales
# 1  Sweet and savory sauces, relishes, spreads, an...
# 2                Desserts, candies, and sweet breads
# 3                                            Cheeses
# 4                Breads, crackers, pasta, and cereal

# %%
cat_prod_df = pd.merge(category_df, product_df, on = "CategoryId" )
cat_prod_df.head()
# Out:
#    CategoryId CategoryName                                  Description  Id  \
# 0           1    Beverages  Soft drinks, coffees, teas, beers, and ales   1
# 1           1    Beverages  Soft drinks, coffees, teas, beers, and ales   2
# 2           1    Beverages  Soft drinks, coffees, teas, beers, and ales  24
# 3           1    Beverages  Soft drinks, coffees, teas, beers, and ales  34
# 4           1    Beverages  Soft drinks, coffees, teas, beers, and ales  35
#
#           ProductName  SupplierId     QuantityPerUnit  UnitPrice  \
# 0                Chai           1  10 boxes x 20 bags       18.0
# 1               Chang           1  24 - 12 oz bottles       19.0
# 2  Guaraná Fantástica          10    12 - 355 ml cans        4.5
# 3       Sasquatch Ale          16  24 - 12 oz bottles       14.0
# 4      Steeleye Stout          16  24 - 12 oz bottles       18.0
#
#    UnitsInStock  UnitsOnOrder  ReorderLevel  Discontinued
# 0            39             0            10             0
# 1            17            40            25             0
# 2            20             0             0             1
# 3           111             0            15             0
# 4            20             0            15             0

# %%
len(cat_prod_df)
# Out:
# 77

# %% [markdown]
# rename Id column on Product Table so I can merge OrderDetail Table

# %%
cat_prod_df.rename(columns = {"Id": "ProductId"}, inplace = True)
cat_prod_df.head(2)
# Out:
#    CategoryId CategoryName                                  Description  \
# 0           1    Beverages  Soft drinks, coffees, teas, beers, and ales
# 1           1    Beverages  Soft drinks, coffees, teas, beers, and ales
#
#    ProductId ProductName  SupplierId     QuantityPerUnit  UnitPrice  \
# 0          1        Chai           1  10 boxes x 20 bags       18.0
# 1          2       Chang           1  24 - 12 oz bottles       19.0
#
#    UnitsInStock  UnitsOnOrder  ReorderLevel  Discontinued
# 0            39             0            10             0
# 1            17            40            25             0

# %%
cat_prod_OrDtl_df = pd.merge(cat_prod_df, orderDetail_df, on = "ProductId")
cat_prod_OrDtl_df.head()
# Out:
#    CategoryId CategoryName                                  Description  \
# 0           1    Beverages  Soft drinks, coffees, teas, beers, and ales
# 1           1    Beverages  Soft drinks, coffees, teas, beers, and ales
# 2           1    Beverages  Soft drinks, coffees, teas, beers, and ales
# 3           1    Beverages  Soft drinks, coffees, teas, beers, and ales
# 4           1    Beverages  Soft drinks, coffees, teas, beers, and ales
#
#    ProductId ProductName  SupplierId     QuantityPerUnit  UnitPrice_x  \
# 0          1        Chai           1  10 boxes x 20 bags         18.0
# 1          1        Chai           1  10 boxes x 20 bags         18.0
# 2          1        Chai           1  10 boxes x 20 bags         18.0
# 3          1        Chai           1  10 boxes x 20 bags         18.0
# 4          1        Chai           1  10 boxes x 20 bags         18.0
#
#    UnitsInStock  UnitsOnOrder  ReorderLevel  Discontinued       Id  OrderId  \
# 0            39             0            10             0  10285/1    10285
# 1            39             0            10             0  10294/1    10294
# 2            39             0            10             0  10317/1    10317
# 3            39             0            10             0  10348/1    10348
# 4            39             0            10             0  10354/1    10354
#
#    UnitPrice_y  Quantity  Discount
# 0         14.4        45      0.20
# 1         14.4        18      0.00
# 2         14.4        20      0.00
# 3         14.4        15      0.15
# 4         14.4        12      0.00

# %%
len(cat_prod_OrDtl_df)
# Out:
# 2155

# %%
order_df.rename(columns = {"Id" : "OrderId"}, inplace = True)

# %%
cat_prod_OrDtl_orders_df = pd.merge(cat_prod_OrDtl_df, order_df, on = "OrderId" )
cat_prod_OrDtl_orders_df.head()
# Out:
#    CategoryId  CategoryName                                  Description  \
# 0           1     Beverages  Soft drinks, coffees, teas, beers, and ales
# 1           6  Meat/Poultry                               Prepared meats
# 2           8       Seafood                             Seaweed and fish
# 3           1     Beverages  Soft drinks, coffees, teas, beers, and ales
# 4           1     Beverages  Soft drinks, coffees, teas, beers, and ales
#
#    ProductId       ProductName  SupplierId     QuantityPerUnit  UnitPrice_x  \
# 0          1              Chai           1  10 boxes x 20 bags         18.0
# 1         53     Perth Pasties          24           48 pieces         32.8
# 2         40  Boston Crab Meat          19      24 - 4 oz tins         18.4
# 3          1              Chai           1  10 boxes x 20 bags         18.0
# 4         43       Ipoh Coffee          20     16 - 500 g tins         46.0
#
#    UnitsInStock  UnitsOnOrder  ReorderLevel  Discontinued        Id  OrderId  \
# 0            39             0            10             0   10285/1    10285
# 1             0             0             0             1  10285/53    10285
# 2           123             0            30             0  10285/40    10285
# 3            39             0            10             0   10294/1    10294
# 4            17            10            25             0  10294/43    10294
#
#    UnitPrice_y  Quantity  Discount CustomerId  EmployeeId   OrderDate  \
# 0         14.4        45       0.2      QUICK           1  2012-08-20
# 1         26.2        36       0.2      QUICK           1  2012-08-20
# 2         14.7        40       0.2      QUICK           1  2012-08-20
# 3         14.4        18       0.0      RATTC           4  2012-08-30
# 4         36.8        15       0.0      RATTC           4  2012-08-30
#
#   RequiredDate ShippedDate  ShipVia  Freight                    ShipName  \
# 0   2012-09-17  2012-08-26        2    76.83                  QUICK-Stop
# 1   2012-09-17  2012-08-26        2    76.83                  QUICK-Stop
# 2   2012-09-17  2012-08-26        2    76.83                  QUICK-Stop
# 3   2012-09-27  2012-09-05        2   147.26  Rattlesnake Canyon Grocery
# 4   2012-09-27  2012-09-05        2   147.26  Rattlesnake Canyon Grocery
#
#         ShipAddress     ShipCity      ShipRegion ShipPostalCode ShipCountry
# 0  Taucherstraße 10    Cunewalde  Western Europe          01307     Germany
# 1  Taucherstraße 10    Cunewalde  Western Europe          01307     Germany
# 2  Taucherstraße 10    Cunewalde  Western Europe          01307     Germany
# 3   2817 Milton Dr.  Albuquerque   North America          87110         USA
# 4   2817 Milton Dr.  Albuquerque   North America          87110         USA

# %%
len(cat_prod_OrDtl_orders_df)
# Out:
# 2155

# %%
customer_df.rename(columns ={"Id": "CustomerId"}, inplace = True)

# %%
df = pd.merge(cat_prod_OrDtl_orders_df, customer_df, on = "CustomerId")
df.head()
# Out:
#    CategoryId  CategoryName                                  Description  \
# 0           1     Beverages  Soft drinks, coffees, teas, beers, and ales
# 1           6  Meat/Poultry                               Prepared meats
# 2           8       Seafood                             Seaweed and fish
# 3           1     Beverages  Soft drinks, coffees, teas, beers, and ales
# 4           1     Beverages  Soft drinks, coffees, teas, beers, and ales
#
#    ProductId       ProductName  SupplierId     QuantityPerUnit  UnitPrice_x  \
# 0          1              Chai           1  10 boxes x 20 bags         18.0
# 1         53     Perth Pasties          24           48 pieces         32.8
# 2         40  Boston Crab Meat          19      24 - 4 oz tins         18.4
# 3          1              Chai           1  10 boxes x 20 bags         18.0
# 4         43       Ipoh Coffee          20     16 - 500 g tins         46.0
#
#    UnitsInStock  UnitsOnOrder  ReorderLevel  Discontinued        Id  OrderId  \
# 0            39             0            10             0   10285/1    10285
# 1             0             0             0             1  10285/53    10285
# 2           123             0            30             0  10285/40    10285
# 3            39             0            10             0   10691/1    10691
# 4            17            10            25             0  10691/43    10691
#
#    UnitPrice_y  Quantity  Discount CustomerId  EmployeeId   OrderDate  \
# 0         14.4        45       0.2      QUICK           1  2012-08-20
# 1         26.2        36       0.2      QUICK           1  2012-08-20
# 2         14.7        40       0.2      QUICK           1  2012-08-20
# 3         18.0        30       0.0      QUICK           2  2013-10-03
# 4         46.0        40       0.0      QUICK           2  2013-10-03
#
#   RequiredDate ShippedDate  ShipVia  Freight    ShipName       ShipAddress  \
# 0   2012-09-17  2012-08-26        2    76.83  QUICK-Stop  Taucherstraße 10
# 1   2012-09-17  2012-08-26        2    76.83  QUICK-Stop  Taucherstraße 10
# 2   2012-09-17  2012-08-26        2    76.83  QUICK-Stop  Taucherstraße 10
# 3   2013-11-14  2013-10-22        2   810.05  QUICK-Stop  Taucherstraße 10
# 4   2013-11-14  2013-10-22        2   810.05  QUICK-Stop  Taucherstraße 10
#
#     ShipCity      ShipRegion ShipPostalCode ShipCountry CompanyName  \
# 0  Cunewalde  Western Europe          01307     Germany  QUICK-Stop
# 1  Cunewalde  Western Europe          01307     Germany  QUICK-Stop
# 2  Cunewalde  Western Europe          01307     Germany  QUICK-Stop
# 3  Cunewalde  Western Europe          01307     Germany  QUICK-Stop
# 4  Cunewalde  Western Europe          01307     Germany  QUICK-Stop
#
#    ContactName        ContactTitle           Address       City  \
# 0  Horst Kloss  Accounting Manager  Taucherstraße 10  Cunewalde
# 1  Horst Kloss  Accounting Manager  Taucherstraße 10  Cunewalde
# 2  Horst Kloss  Accounting Manager  Taucherstraße 10  Cunewalde
# 3  Horst Kloss  Accounting Manager  Taucherstraße 10  Cunewalde
# 4  Horst Kloss  Accounting Manager  Taucherstraße 10  Cunewalde
#
#            Region PostalCode  Country        Phone   Fax
# 0  Western Europe      01307  Germany  0372-035188  None
# 1  Western Europe      01307  Germany  0372-035188  None
# 2  Western Europe      01307  Germany  0372-035188  None
# 3  Western Europe      01307  Germany  0372-035188  None
# 4  Western Europe      01307  Germany  0372-035188  None

# %%
len(df)
# Out:
# 2078

# %%
q1df = copy.deepcopy(df[["Quantity", "Discount"]])
q1df.head()
# Out:
#    Quantity  Discount
# 0        45       0.2
# 1        36       0.2
# 2        40       0.2
# 3        30       0.0
# 4        40       0.0

# %%
len(q1df)
# Out:
# 2078

# %%
q1df.Discount.unique()
# Out:
# array([0.2 , 0.  , 0.25, 0.1 , 0.05, 0.15, 0.02, 0.03, 0.04, 0.06, 0.01])

# %%
q1df.Discount.value_counts()
# Out:
# 0.00    1272
# 0.05     179
# 0.10     164
# 0.20     158
# 0.15     150
# 0.25     147
# 0.03       3
# 0.02       2
# 0.01       1
# 0.04       1
# 0.06       1
# Name: Discount, dtype: int64

# %% [markdown]
# ##### discounts of 1%, 2%, 3%, 4% and 6% are so infrequent that there are not enough observations to give meaningful insights
# will drop these obserations from the data set.

# %% [markdown]
# ## EDA

# %%
q1df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2078 entries, 0 to 2077
# Data columns (total 2 columns):
# Quantity    2078 non-null int64
# Discount    2078 non-null float64
# dtypes: float64(1), int64(1)
# memory usage: 48.7 KB

# %%
fig, axes = plt.subplots(nrows = 1, ncols = 4, figsize = (20,3))

for xcol, ax in zip(['Discount'], axes):
    q1df.plot(kind = 'scatter', x=xcol, y='Quantity', ax=ax, alpha=0.4, color='b')

# %%
q1df.head()
# Out:
#    Quantity  Discount
# 0        45       0.2
# 1        36       0.2
# 2        40       0.2
# 3        30       0.0
# 4        40       0.0

# %%
len(q1df)
# Out:
# 2078

# %%
discountDf = q1df.groupby("Discount")
discountDf["Quantity"].mean()
# Out:
# Discount
# 0.00    21.900943
# 0.01     2.000000
# 0.02     2.000000
# 0.03     1.666667
# 0.04     1.000000
# 0.05    27.972067
# 0.06     2.000000
# 0.10    25.396341
# 0.15    28.773333
# 0.20    26.987342
# 0.25    27.829932
# Name: Quantity, dtype: float64

# %% [markdown]
# ##  Question 1
#
#     *  Do discounts have a statistically significant effect on the number of products customers order?
#     *  if so, at what level(s) of discount?

# %% [markdown]
# h0: mean sales with discount = mean sales w/o discount
# h1: mean sales with discount > mean sales w/o discount
#
# h0 = customer orders with discounts are equal to customer orders without discounts<br>
# h1 = customer orders with discounts are greater than customer orders without discounts<br>
# this is a one tailed test

# %% [markdown]
# whats the average...are orders with discounts greater than the average?

# %% [markdown]
# ##### T-Test
# ##### separate observations by the discount levels

# %%
zeroP = q1df[q1df["Discount"]==0.0]
oneP = q1df[q1df["Discount"]==0.01]
twoP = q1df[q1df["Discount"]==0.02]
threeP = q1df[q1df["Discount"]==0.03]
fourP = q1df[q1df["Discount"]==0.04]
fiveP = q1df[q1df["Discount"]==0.05]
sixP = q1df[q1df["Discount"]==0.6]
tenP = q1df[q1df["Discount"]==0.10]
fifteenP = q1df[q1df["Discount"]==0.15]
twentyP = q1df[q1df["Discount"]==0.20]
twentyFiveP = q1df[q1df["Discount"]==0.25]

# %%
zeroP.head()
# Out:
#    Quantity  Discount
# 3        30       0.0
# 4        40       0.0
# 5        24       0.0
# 6        48       0.0
# 7        40       0.0

# %%
zeroP.Quantity.mean()
# Out:
# 21.900943396226417
